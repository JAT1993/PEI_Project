# %%
import pytest
import sys
import pyspark.sql.functions as F
from pyspark.sql import Row
from pyspark.sql.types import *
from pyspark.testing import assertDataFrameEqual

# Injects your production pipeline functions into this notebook's memory space
# %run ./your_production_pipeline_notebook

# Helper to generate mock Spark sessions or schemas quickly inside tests
@pytest.fixture(scope="session")
def order_schema():
    return StructType([
        StructField("RowID", IntegerType(), True),
        StructField("OrderID", StringType(), True),
        StructField("CustomerID", StringType(), True),
        StructField("ProductID", StringType(), True),
        StructField("OrderDate", StringType(), True),
        StructField("ShipDate", StringType(), True),
        StructField("Quantity", IntegerType(), True),
        StructField("Price", DoubleType(), True),
        StructField("Discount", DoubleType(), True),
        StructField("Profit", DoubleType(), True),
        StructField("ShipMode", StringType(), True)
    ])
