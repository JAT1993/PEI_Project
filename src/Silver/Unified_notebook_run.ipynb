# %%
dbutils.notebook.run(
    "/Workspace/Users/jatin.march1993.arora@gmail.com/PEI_Project/src/Silver/Unified_write",7200,
    {
        "cust_bronze": "assessment.bronze.customer",
        "ord_bronze": "assessment.bronze.orders",
        "prod_bronze": "assessment.bronze.product",
        "cust_accept": "assessment.silver.customer_dqc_accepted",
        "ord_accept": "assessment.silver.orders_dqc_accepted",
        "prod_accept": "assessment.silver.product_dqc_accepted",
        "cust_reject": "assessment.silver.customer_dqc_rejected",
        "ord_reject": "assessment.silver.orders_dqc_rejected",
        "prod_reject": "assessment.silver.product_dqc_rejected"
    }
)
