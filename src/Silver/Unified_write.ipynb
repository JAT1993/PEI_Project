# %%
# %run ./Unified_ecomm

# %%
customer_bronze=dbutils.widgets.get('cust_bronze')
orders_bronze=dbutils.widgets.get('ord_bronze')
product_bronze=dbutils.widgets.get('prod_bronze')
customer_accept=dbutils.widgets.get('cust_accept')
orders_accept=dbutils.widgets.get('ord_accept')
product_accept=dbutils.widgets.get('prod_accept')
customer_reject=dbutils.widgets.get('cust_reject')
orders_reject=dbutils.widgets.get('ord_reject')
product_reject=dbutils.widgets.get('prod_reject')

# %%
dqc_checks_write(product_bronze,product_accept,product_reject)

# %%
dqc_checks_write(customer_bronze,customer_accept,customer_reject)

# %%
dqc_checks_write(orders_bronze,orders_accept,orders_reject)
