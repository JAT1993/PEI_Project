# %%
dbutils.notebook.run(
    "/Workspace/Users/jatin.march1993.arora@gmail.com/PEI_Project/src/Gold/publish_write",7200,
    {
        "orders_dqc": "assessment.silver.orders_dqc_accepted",
        "customer_dqc": "assessment.silver.customer_dqc_accepted",
        "product_dqc": "assessment.silver.product_dqc_accepted",
        "enriched_orders": "assessment.gold.enriched_orders_summary",
        "enriched_customer_prod": "assessment.gold.enriched_customer_products",
        "enriched_order_summ": "assessment.gold.enriched_orders_summary",
        "enriched_sales_anal": "assessment.gold.enriched_sales_analysis",
        "aggr_profit_summ": "assessment.gold.aggregated_profit_summary",
        "report_profit_year": "assessment.gold.report_profit_by_year",
        "report_profit_year_cat": "assessment.gold.report_profit_by_year_category",
        "report_profit_by_cust": "assessment.gold.report_profit_by_customer",
        "report_profit_by_cust_year": "assessment.gold.report_profit_by_customer_year"

    }
)
