# %%
# %run ./landing_ecomm.py

# %%
# excel_write("assessment.bronze.customer","/Workspace/Users/jatin.march1993.arora@gmail.com/PEI_Project/data/Customer.xlsx")

# %%
csv_write("assessment.bronze.product","/Volumes/assessment/bronze/bronze_product/Products.csv")

# %%
json_write("assessment.bronze.orders","/Volumes/assessment/bronze/bronze_orders/Orders.json")
