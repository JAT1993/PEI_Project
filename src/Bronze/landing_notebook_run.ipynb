# %%
dbutils.notebook.run(
    "/Workspace/Users/jatin.march1993.arora@gmail.com/PEI_Project/src/Bronze/landing_write",7200,
    {
        "cust_table_name": "assessment.bronze.customer",
        "orders_table_name": "assessment.bronze.orders",
        "product_table_name": "assessment.bronze.product",
        "cust_path_name": "/Volumes/assessment/bronze/bronze_customer/Customer.xlsx",
        "orders_path_name": "/Volumes/assessment/bronze/bronze_orders/Orders.json",
        "product_path_name": "/Volumes/assessment/bronze/bronze_product/Products.csv"
    }
)
