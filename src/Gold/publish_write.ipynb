# %%
# %run ./publish_ecomm

# %%
orders_silver=dbutils.widgets.get('orders_dqc')
cust_silver=dbutils.widgets.get('customer_dqc')
products_silver=dbutils.widgets.get('product_dqc')
enriched_orders_summary=dbutils.widgets.get('enriched_orders')
enriched_customer_products=dbutils.widgets.get('enriched_customer_prod')
enriched_order_summary=dbutils.widgets.get('enriched_order_summ')
enriched_sales_analysis=dbutils.widgets.get('enriched_sales_anal')
aggregated_profit_summary=dbutils.widgets.get('aggr_profit_summ')
report_profit_by_year=dbutils.widgets.get('report_profit_year')
report_profit_by_year_category=dbutils.widgets.get('report_profit_year_cat')
report_profit_by_customer=dbutils.widgets.get('report_profit_by_cust')
report_profit_by_customer_year=dbutils.widgets.get('report_profit_by_cust_year')

# %%
publish_write(orders_silver,cust_silver,products_silver,enriched_orders_summary,enriched_customer_products)

# %%
publish_write(orders_silver,cust_silver,products_silver,enriched_orders_summary,enriched_sales_analysis)

# %%
publish_write(orders_silver,cust_silver,products_silver,enriched_orders_summary,enriched_orders_summary)

# %%
publish_write(orders_silver,cust_silver,products_silver,enriched_orders_summary,aggregated_profit_summary)

# %%
publish_write(orders_silver,cust_silver,products_silver,enriched_orders_summary,report_profit_by_year)

# %%
publish_write(orders_silver,cust_silver,products_silver,enriched_orders_summary,report_profit_by_year_category)

# %%
publish_write(orders_silver,cust_silver,products_silver,enriched_orders_summary,report_profit_by_customer)

# %%
publish_write(orders_silver,cust_silver,products_silver,enriched_orders_summary,report_profit_by_customer_year)
