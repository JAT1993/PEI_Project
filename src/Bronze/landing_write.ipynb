# %%
# %run ./landing_ecomm

# %%
customer_table=dbutils.widgets.get('cust_table_name')
orders_table=dbutils.widgets.get('orders_table_name')
product_table=dbutils.widgets.get('product_table_name')
customer_path=dbutils.widgets.get('cust_path_name')
orders_path=dbutils.widgets.get('orders_path_name')
product_path=dbutils.widgets.get('product_path_name')

# %%
excel_write(customer_table,customer_path)

# %%
csv_write(product_table,product_path)

# %%
json_write(orders_table,orders_path)
