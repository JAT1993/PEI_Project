# %%
# %run ./Unified_ecomm.py

# %%
dqc_checks_write("assessment.bronze.product","assessment.silver.product_dqc_rejected","assessment.silver.product_dqc_rejected")

# %%
dqc_checks_write("assessment.bronze.customer","assessment.silver.customer_dqc_rejected","assessment.silver.customer_dqc_rejected")

# %%
dqc_checks_write("assessment.bronze.orders","assessment.silver.orders_dqc_rejected","assessment.silver.orders_dqc_rejected")
